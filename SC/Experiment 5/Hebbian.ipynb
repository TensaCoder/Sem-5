# %%
import numpy as np

def bipolarSigmoid(x,steepness):
    expValue= steepness * x
    return (1 - np.exp(-expValue))/(1+ np.exp(-expValue))

def sgn(x):
    if x>=0: 
        return 1
    else: 
        return -1

# needs w, x, alpha
def hebbianBipolarLearning(w, x, alpha):
    epoch =0
    # iteration over all input 3 times
    while (epoch <3):
        for i in range(len(x)):
            net = w[0]*x[i][0] + w[1]*x[i][1] + w[2]*x[i][2] + w[3]*x[i][3]
            oiBipolar = sgn(net)

            #modifying the weights
            wDeltaVal = alpha * oiBipolar
            wDelta =[
                wDeltaVal*x[i][0],
                wDeltaVal*x[i][1],
                wDeltaVal*x[i][2],
                wDeltaVal*x[i][3]
            ]
            w = [
                w[0] + wDelta[0],
                w[1] + wDelta[1],
                w[2] + wDelta[2],
                w[3] + wDelta[3]
            ]
            print("Changing Value of Weights : ", w)

        epoch+=1
    
    return w

# needs w, x, steepness, 
def hebbianSigmoidLearning(w, x, alpha, steepness):
    epoch =0
    # iteration over all input 3 times
    while (epoch <3):
        for i in range(len(x)):
            net = w[0]*x[i][0] + w[1]*x[i][1] + w[2]*x[i][2] + w[3]*x[i][3]
            # print("Net: ", net)
            oiSigmoid = bipolarSigmoid(net, steepness)
            print("f(net)", oiSigmoid)

            #modifying the weights
            wDeltaVal = alpha * oiSigmoid
            wDelta =[
                wDeltaVal*x[i][0],
                wDeltaVal*x[i][1],
                wDeltaVal*x[i][2],
                wDeltaVal*x[i][3]
            ]
            w = [
                w[0] + wDelta[0],
                w[1] + wDelta[1],
                w[2] + wDelta[2],
                w[3] + wDelta[3]
            ]
            print("Changing Value of Weights : ", w)

        epoch+=1
    
    return w


w = [1, -1, 0, 0.5]
x=[[1, -2, 1.5, 0], [1, -0.5, -2, -1.5], [0, 1, -1, 1.5]]
steepness = 1
alpha = 1


print("For Biploar Activation Hebbian Learning:")
finalWeights = hebbianBipolarLearning(w,x,alpha)
print("\nThe final weights for Bipolar Hebbain Learning : ", finalWeights)


print("\n\nFor Biploar Sigmoid Activation Hebbian Learning:")
finalSigmoidWeights = hebbianSigmoidLearning(w, x, alpha, steepness)
print("\nThe final weights for Bipolar Hebbain Learning : ", finalSigmoidWeights)
# Out:
# For Biploar Activation Hebbian Learning:
# Changing Value of Weights :  [2, -3, 1.5, 0.5]
# Changing Value of Weights :  [1, -2.5, 3.5, 2.0]
# Changing Value of Weights :  [1, -3.5, 4.5, 0.5]
# Changing Value of Weights :  [2, -5.5, 6.0, 0.5]
# Changing Value of Weights :  [1, -5.0, 8.0, 2.0]
# Changing Value of Weights :  [1, -6.0, 9.0, 0.5]
# Changing Value of Weights :  [2, -8.0, 10.5, 0.5]
# Changing Value of Weights :  [1, -7.5, 12.5, 2.0]
# Changing Value of Weights :  [1, -8.5, 13.5, 0.5]
#
# The final weights for Bipolar Hebbain Learning :  [1, -8.5, 13.5, 0.5]
#
#
# For Biploar Sigmoid Activation Hebbian Learning:
# Net:  3.0
# f(net) 0.9051482536448665
# Changing Value of Weights :  [1.9051482536448665, -2.810296507289733, 1.3577223804672998, 0.5]
# Net:  -0.1551482536448665
# f(net) -0.07741889336533982
# Changing Value of Weights :  [1.8277293602795266, -2.771587060607063, 1.5125601671979794, 0.6161283400480098]
# Net:  -3.359954717733028
# f(net) -0.9328586152504333
# Changing Value of Weights :  [1.8277293602795266, -3.7044456758574964, 2.445418782448413, -0.7831595828276403]
# Net:  12.904748885667138
# f(net) 0.9999950275813748
# Changing Value of Weights :  [2.8277243878609015, -5.704435731020246, 3.9454113238204753, -0.7831595828276403]
# Net:  -1.036141020028466
# f(net) -0.4762094545678837
# Changing Value of Weights :  [2.351514933293018, -5.466331003736304, 4.897830232956243, -0.06884540097581471]
# Net:  -10.467429338156268
# f(net) -0.9999431054273442
# Changing Value of Weights :  [2.351514933293018, -6.466274109163648, 5.897773338383587, -1.5687600591168311]
# Net:  24.130723159195696
# f(net) 0.9999999999337494
# Changing Value of Weights :  [3.3515149332267673, -8.466274109031147, 7.397773338284211, -1.5687600591168311]
# Net:  -4.857754600150836
# f(net) -0.9845839377693408
# Changing Value of Weights :  [2.3669309954574267, -7.973982140146477, 9.366941213822892, -0.09188415246282]
# Net:  -17.4787495826636
# f(net) -0.9999999487014026
# Changing Value of Weights :  [2.3669309954574267, -8.97398208884788, 10.366941162524295, -1.591884075514924]
#
# The final weights for Bipolar Hebbain Learning :  [2.3669309954574267, -8.97398208884788, 10.366941162524295, -1.591884075514924]
